# %%
import tweepy
import pandas as pd
auth = tweepy.OAuth2BearerHandler("AAAAAAAAAAAAAAAAAAAAALZuiQEAAAAAZ%2BMF86p%2Bby1dR63PIHQpNtxldH0%3Dj1Y1A6L51JNTLAeWqqfI3z2op9icp357HPgGCozL10lfXwThen")
api = tweepy.API(auth)

# %%
consumer_key = "" #Your API/Consumer key 
consumer_secret = "" #Your API/Consumer Secret Key
access_token = ""    #Your Access token key
access_token_secret = "" #Your Access token Secret key

# %%
#Pass in our twitter API authentication key
auth = tweepy.OAuth1UserHandler(
   consumer_key, consumer_secret,
   access_token, access_token_secret
)

# %%
#Instantiate the tweepy API
api = tweepy.API(auth, wait_on_rate_limit=True)


username = "zomato"
no_of_tweets =70

# %%
try:
    #The number of tweets we want to retrieved from the user
    tweets = api.user_timeline(screen_name=username, count=no_of_tweets)
    
    #Pulling Some attributes from the tweet
    attributes_container = [[tweet.id,tweet.created_at,tweet.favorite_count,tweet.source,
                             tweet.text,tweet.lang,tweet.user.screen_name,
                            tweet.in_reply_to_status_id_str,tweet.retweet_count,
                             tweet.entities,tweet.user.location,tweet.user.created_at
                            ] for tweet in tweets]

    #Creation of column list to rename the columns in the dataframe
    columns = ["tweetID","Date_Created", "Number_of_Likes", "Source_of_Tweet", "Tweet","language","username","inreplyto_status_id","retweet_count","entities","location","user_created"]
    #Creation of Dataframe
    tweets_df = pd.DataFrame(attributes_container, columns=columns)
except BaseException as e:
    print('Status Failed On,',str(e))
    time.sleep(3)

# %%
tweets_df.head() #head and tail for first and last.
# Out:
#                tweetID              Date_Created  Number_of_Likes  \
# 0  1603131602779123712 2022-12-14 20:55:33+00:00              463
# 1  1602154785549213696 2022-12-12 04:14:02+00:00             1103
# 2  1601644760485490688 2022-12-10 18:27:22+00:00             2509
# 3  1601622324893343745 2022-12-10 16:58:13+00:00              614
# 4  1600739451600150528 2022-12-08 06:30:00+00:00              775
#
#        Source_of_Tweet                                              Tweet  \
# 0  Twitter for Android  It's ok Morocco, you might not have won the wo...
# 1      Twitter Web App  happy birthday @rajinikanth sir\nvayyasanalum ...
# 2      Twitter Web App  who's cutting the onions at midnight 💔 https:/...
# 3  Twitter for Android           the underdogs beat the GOAT!!!!!!!!!!!!!
# 4      Twitter Web App        the best thing about chai is that it exists
#
#   language username inreplyto_status_id  retweet_count  \
# 0       en   zomato                None             26
# 1       in   zomato                None            599
# 2       en   zomato                None             88
# 3       en   zomato                None             20
# 4       en   zomato                None             71
#
#                                             entities  location  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...  India 🇮🇳
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...  India 🇮🇳
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...  India 🇮🇳
# 3  {'hashtags': [], 'symbols': [], 'user_mentions...  India 🇮🇳
# 4  {'hashtags': [], 'symbols': [], 'user_mentions...  India 🇮🇳
#
#                user_created
# 0 2009-03-08 06:18:24+00:00
# 1 2009-03-08 06:18:24+00:00
# 2 2009-03-08 06:18:24+00:00
# 3 2009-03-08 06:18:24+00:00
# 4 2009-03-08 06:18:24+00:00

# %%
username_grubhub = "grubhub"
no_of_tweets_grubhub =30

# %%
try:
    #The number of tweets we want to retrieved from the user
    tweets = api.user_timeline(screen_name=username_grubhub, count=no_of_tweets_grubhub)
    
    #Pulling Some attributes from the tweet
# 6   BrandBastion Platform  @PicksThatWinNFL Let's look into this for you....
# 7   BrandBastion Platform              @AlwaysANinerFan We love to hear it 🔥
# 8      Twitter for iPhone                          @arboshah We ❤️ ranch too
# 9   BrandBastion Platform  @broadway_kb Hey! You can unwrap all your stat...
# 10     Twitter for iPhone                @Kannon90210 One of our favorites 🍟
# 11     Twitter for iPhone                             @CZantolski The best 🍕
# 12     Twitter for iPhone                @BaBy_BoyZ_MaMi We’re here for it 👏
# 13     Twitter for iPhone                    @tarabella_21 Hey, we get it ☕️
# 14     Twitter for iPhone                               @sbartwork24 Classic
# 15     Twitter for iPhone                                  @Rosa46977745 YUM
# 16  BrandBastion Platform                    @Nisaalink We love to hear it 🔥
# 17     Twitter for iPhone  So… what was everyone’s most ordered item? #20...
# 18     Twitter for iPhone              @IamBrewster Really spicing things up
# 19     Twitter for iPhone                                        @flaniel_ 👀
# 20     Twitter for iPhone                            @AnneJcobs Yes we did 🤝
# 21     Twitter for iPhone           @ncavicchio Fried dumplings? Count us in
# 22     Twitter for iPhone             @LouisPeitzman Not even a little peek?
# 23              TweetDeck          @oat_chai_ The people asked, we delivered
# 24              TweetDeck         @luxurytrash_ Chicken quesadillas though 🔥
# 25              TweetDeck                      @aviciouskoala absolutely yes
# 26              TweetDeck             @Chris_Thats_Me Big pretzel stick fan?
# 27              TweetDeck  @XxFinalGirlxX We don’t like to compare, but i...
# 28  BrandBastion Platform                                      @anatlus89 🔥🔥
# 29  BrandBastion Platform  @Utmb_Colorado Let's look into this for you. D...
#
#    language username  inreplyto_status_id  retweet_count  \
# 0        en  Grubhub  1603172381614542848              0
# 1        en  Grubhub  1603182951663116289              0
# 2        en  Grubhub  1603187209326432257              0
# 3        en  Grubhub  1603100286205280257              0
# 4        en  Grubhub                 None              1
# 5        es  Grubhub                 None              1
# 6        en  Grubhub  1603159587099742208              0
# 7        en  Grubhub  1603150045691273216              0
# 8        en  Grubhub  1603111524922335233              1
# 9        en  Grubhub  1603148163732357120              0
# 10       en  Grubhub  1603143896204283906              0
# 11       en  Grubhub  1603143439595487234              0
# 12       en  Grubhub  1603144601883344897              0
# 13       en  Grubhub  1603144158088044546              0
# 14       en  Grubhub  1603145202746773506              0
# 15      und  Grubhub  1603145356409073664              0
# 16       en  Grubhub  1603128491532320771              0
# 17       en  Grubhub                 None              3
# 18       en  Grubhub  1603100179368148992              0
# 19      und  Grubhub  1603135280482906112              0
# 20       en  Grubhub  1603085538851954690              0
# 21       en  Grubhub  1603087285053947905              0
# 22       en  Grubhub  1603073395297767424              0
# 23       en  Grubhub  1603130593264271360              0
# 24       en  Grubhub  1603129147248738304              0
# 25       en  Grubhub  1603123319045124096              0
# 26       en  Grubhub  1603122037429571592              0
# 27       en  Grubhub  1603118851121635328              0
# 28      und  Grubhub  1603119750116098048              0
# 29       en  Grubhub  1603112232367161344              0
#
#                                              entities  location  \
# 0   {'hashtags': [], 'symbols': [], 'user_mentions...  New York
# 1   {'hashtags': [], 'symbols': [], 'user_mentions...  New York
# 2   {'hashtags': [], 'symbols': [], 'user_mentions...  New York
# 3   {'hashtags': [], 'symbols': [], 'user_mentions...  New York
# 4   {'hashtags': [], 'symbols': [], 'user_mentions...  New York
# 5   {'hashtags': [], 'symbols': [], 'user_mentions...  New York
# 6   {'hashtags': [], 'symbols': [], 'user_mentions...  New York
# 7   {'hashtags': [], 'symbols': [], 'user_mentions...  New York
# 8   {'hashtags': [], 'symbols': [], 'user_mentions...  New York
# 9   {'hashtags': [], 'symbols': [], 'user_mentions...  New York
# 10  {'hashtags': [], 'symbols': [], 'user_mentions...  New York
# 11  {'hashtags': [], 'symbols': [], 'user_mentions...  New York
# 12  {'hashtags': [], 'symbols': [], 'user_mentions...  New York
# 13  {'hashtags': [], 'symbols': [], 'user_mentions...  New York
# 14  {'hashtags': [], 'symbols': [], 'user_mentions...  New York
#
#    language username  inreplyto_status_id  retweet_count  \
# 0        en   zomato                 None             26
# 1        in   zomato                 None            599
# 2        en   zomato                 None             88
# 3        en   zomato                 None             20
# 4        en   zomato                 None             71
# ..      ...      ...                  ...            ...
# 95       en  Grubhub  1603123319045124096              0
# 96       en  Grubhub  1603122037429571592              0
# 97       en  Grubhub  1603118851121635328              0
# 98      und  Grubhub  1603119750116098048              0
# 99       en  Grubhub  1603112232367161344              0
#
#                                              entities  location  \
# 0   {'hashtags': [], 'symbols': [], 'user_mentions...  India 🇮🇳
# 1   {'hashtags': [], 'symbols': [], 'user_mentions...  India 🇮🇳
# 2   {'hashtags': [], 'symbols': [], 'user_mentions...  India 🇮🇳
# 3   {'hashtags': [], 'symbols': [], 'user_mentions...  India 🇮🇳
# 4   {'hashtags': [], 'symbols': [], 'user_mentions...  India 🇮🇳
# ..                                                ...       ...
# 95  {'hashtags': [], 'symbols': [], 'user_mentions...  New York
# 96  {'hashtags': [], 'symbols': [], 'user_mentions...  New York
# 97  {'hashtags': [], 'symbols': [], 'user_mentions...  New York
# 98  {'hashtags': [], 'symbols': [], 'user_mentions...  New York
# 99  {'hashtags': [], 'symbols': [], 'user_mentions...  New York
#
#                 user_created
# 0  2009-03-08 06:18:24+00:00
# 1  2009-03-08 06:18:24+00:00
# 2  2009-03-08 06:18:24+00:00
# 3  2009-03-08 06:18:24+00:00
# 4  2009-03-08 06:18:24+00:00
# ..                       ...
# 95 2008-08-18 22:19:47+00:00
# 96 2008-08-18 22:19:47+00:00
# 97 2008-08-18 22:19:47+00:00
# 98 2008-08-18 22:19:47+00:00
# 99 2008-08-18 22:19:47+00:00
#
# [100 rows x 12 columns]

# %%
df.to_csv('./tweet_Username.csv', index = False)

# %%
e=pd.read_csv("tweet_Username.csv")

# %%
e.head()
# Out:
#                tweetID               Date_Created  Number_of_Likes  \
# 0  1603131602779123712  2022-12-14 20:55:33+00:00              463
# 1  1602154785549213696  2022-12-12 04:14:02+00:00             1103
# 2  1601644760485490688  2022-12-10 18:27:22+00:00             2509
# 3  1601622324893343745  2022-12-10 16:58:13+00:00              614
# 4  1600739451600150528  2022-12-08 06:30:00+00:00              775
#
#        Source_of_Tweet                                              Tweet  \
# 0  Twitter for Android  It's ok Morocco, you might not have won the wo...
# 1      Twitter Web App  happy birthday @rajinikanth sir\nvayyasanalum ...
# 2      Twitter Web App  who's cutting the onions at midnight 💔 https:/...
# 3  Twitter for Android           the underdogs beat the GOAT!!!!!!!!!!!!!
# 4      Twitter Web App        the best thing about chai is that it exists
#
#   language username  inreplyto_status_id  retweet_count  \
# 0       en   zomato                  NaN             26
# 1       in   zomato                  NaN            599
# 2       en   zomato                  NaN             88
# 3       en   zomato                  NaN             20
# 4       en   zomato                  NaN             71
#
#                                             entities  location  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...  India 🇮🇳
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...  India 🇮🇳
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...  India 🇮🇳
# 3  {'hashtags': [], 'symbols': [], 'user_mentions...  India 🇮🇳
# 4  {'hashtags': [], 'symbols': [], 'user_mentions...  India 🇮🇳
#
#                 user_created
# 0  2009-03-08 06:18:24+00:00
# 1  2009-03-08 06:18:24+00:00
# 2  2009-03-08 06:18:24+00:00
# 3  2009-03-08 06:18:24+00:00
# 4  2009-03-08 06:18:24+00:00

# %%
try:
    tweet1 = tweepy.Cursor(api.search_tweets, q = 'zomato').items(100)
    hashtag_container = [[tweet.created_at,tweet.text,tweet.user.screen_name] for tweet in tweet1]
    columns1 = ["ht_Createdatlast24hrs","ht_text","ht_userid"]

    tweets_df1 = pd.DataFrame(hashtag_container, columns=columns1)
except BaseException as e:
    print('Status Failed On,',str(e))
    time.sleep(3)

# %%
tweets_df1
# Out:
#        ht_Createdatlast24hrs  \
# 0  2022-12-15 04:21:06+00:00
# 1  2022-12-15 04:20:18+00:00
# 2  2022-12-15 04:18:19+00:00
# 3  2022-12-15 04:14:01+00:00
# 4  2022-12-15 04:11:46+00:00
# ..                       ...
# 95 2022-12-14 21:20:36+00:00
# 96 2022-12-14 21:08:21+00:00
# 97 2022-12-14 21:07:28+00:00
# 98 2022-12-14 21:07:26+00:00
# 99 2022-12-14 21:06:26+00:00
#
#                                               ht_text        ht_userid
# 0   @desiTraveler @Swiggy @zomato They will have t...       TweetsAnup
# 1   RT @bk191305: @zomatocare meri id 14 dec 2022 ...         bk191305
# 2   Zomato flirting skills &gt;&gt;&gt;&gt; \n\n@z...       Rk__mishra
# 3   @zomatocare meri id 14 dec 2022 ko evening me ...         bk191305
# 4                      @GhazalAlagh Zomato and swiggy  thekomalchauhan
# ..                                                ...              ...
# 95  @zomato Morocco nahi pata but ye sahi nahi hai x(       itsmeachin
# 96  @deepigoyal Look what Zomato hume gives us on ...         vk770625
# 97  @Sanju27029909 @zomatocare @zomato The busines...       Peeyush_13
# 98  @zomato Zomato dekh ke tweet kar... Boycott ho...          imrpind
# 99  @zomato Aa gaye sullo ki chatne https://t.co/u...    Odia_Haalchal
#
# [100 rows x 3 columns]

# %%
tweets_df1.to_csv('./tweet_Hashtag.csv', index = False)

# %%
tweets_df1=pd.read_csv("tweet_Hashtag.csv")

# %%
tweets_df1.head()
# Out:
#        ht_Createdatlast24hrs  \
# 0  2022-12-15 04:21:06+00:00
# 1  2022-12-15 04:20:18+00:00
# 2  2022-12-15 04:18:19+00:00
# 3  2022-12-15 04:14:01+00:00
# 4  2022-12-15 04:11:46+00:00
#
#                                              ht_text        ht_userid
# 0  @desiTraveler @Swiggy @zomato They will have t...       TweetsAnup
# 1  RT @bk191305: @zomatocare meri id 14 dec 2022 ...         bk191305
# 2  Zomato flirting skills &gt;&gt;&gt;&gt; \n\n@z...       Rk__mishra
# 3  @zomatocare meri id 14 dec 2022 ko evening me ...         bk191305
# 4                     @GhazalAlagh Zomato and swiggy  thekomalchauhan

# %%
df1 = pd.concat([df,tweets_df1], axis=1)

# %%
df1.head(100)
# Out:
#                 tweetID              Date_Created  Number_of_Likes  \
# 0   1603131602779123712 2022-12-14 20:55:33+00:00              463
# 1   1602154785549213696 2022-12-12 04:14:02+00:00             1103
# 2   1601644760485490688 2022-12-10 18:27:22+00:00             2509
# 3   1601622324893343745 2022-12-10 16:58:13+00:00              614
# 4   1600739451600150528 2022-12-08 06:30:00+00:00              775
# ..                  ...                       ...              ...
# 95  1603130543704608773 2022-12-14 20:51:21+00:00                0
# 96  1603130484002791424 2022-12-14 20:51:06+00:00                0
# 97  1603129863719817218 2022-12-14 20:48:38+00:00                2
# 98  1603129492846874632 2022-12-14 20:47:10+00:00                1
# 99  1603129452384292864 2022-12-14 20:47:00+00:00                0
#
#           Source_of_Tweet                                              Tweet  \
# 0     Twitter for Android  It's ok Morocco, you might not have won the wo...
# 1         Twitter Web App  happy birthday @rajinikanth sir\nvayyasanalum ...
# 2         Twitter Web App  who's cutting the onions at midnight 💔 https:/...
# 3     Twitter for Android           the underdogs beat the GOAT!!!!!!!!!!!!!
# 4         Twitter Web App        the best thing about chai is that it exists
# ..                    ...                                                ...
# 95              TweetDeck                      @aviciouskoala absolutely yes
# 96              TweetDeck             @Chris_Thats_Me Big pretzel stick fan?
# 97              TweetDeck  @XxFinalGirlxX We don’t like to compare, but i...
# 98  BrandBastion Platform                                      @anatlus89 🔥🔥
# 99  BrandBastion Platform  @Utmb_Colorado Let's look into this for you. D...
#
#    language username  inreplyto_status_id  retweet_count  \
# 0        en   zomato                 None             26
# 1        in   zomato                 None            599
# 2        en   zomato                 None             88
# 3        en   zomato                 None             20
# 4        en   zomato                 None             71
# ..      ...      ...                  ...            ...
# 95       en  Grubhub  1603123319045124096              0
# 96       en  Grubhub  1603122037429571592              0
# 97       en  Grubhub  1603118851121635328              0
# 98      und  Grubhub  1603119750116098048              0
# 99       en  Grubhub  1603112232367161344              0
#
#                                              entities  location  \
# 0   {'hashtags': [], 'symbols': [], 'user_mentions...  India 🇮🇳
# 1   {'hashtags': [], 'symbols': [], 'user_mentions...  India 🇮🇳
# 2   {'hashtags': [], 'symbols': [], 'user_mentions...  India 🇮🇳
# 3   {'hashtags': [], 'symbols': [], 'user_mentions...  India 🇮🇳
# 4   {'hashtags': [], 'symbols': [], 'user_mentions...  India 🇮🇳
# ..                                                ...       ...
# 95  {'hashtags': [], 'symbols': [], 'user_mentions...  New York
# 96  {'hashtags': [], 'symbols': [], 'user_mentions...  New York
# 97  {'hashtags': [], 'symbols': [], 'user_mentions...  New York
# 98  {'hashtags': [], 'symbols': [], 'user_mentions...  New York
# 99  {'hashtags': [], 'symbols': [], 'user_mentions...  New York
#
#                 user_created      ht_Createdatlast24hrs  \
# 0  2009-03-08 06:18:24+00:00  2022-12-15 04:21:06+00:00
# 1  2009-03-08 06:18:24+00:00  2022-12-15 04:20:18+00:00
# 2  2009-03-08 06:18:24+00:00  2022-12-15 04:18:19+00:00
# 3  2009-03-08 06:18:24+00:00  2022-12-15 04:14:01+00:00
# 4  2009-03-08 06:18:24+00:00  2022-12-15 04:11:46+00:00
# ..                       ...                        ...
# 95 2008-08-18 22:19:47+00:00  2022-12-14 21:20:36+00:00
# 96 2008-08-18 22:19:47+00:00  2022-12-14 21:08:21+00:00
# 97 2008-08-18 22:19:47+00:00  2022-12-14 21:07:28+00:00
# 98 2008-08-18 22:19:47+00:00  2022-12-14 21:07:26+00:00
# 99 2008-08-18 22:19:47+00:00  2022-12-14 21:06:26+00:00
#
#                                               ht_text        ht_userid
# 0   @desiTraveler @Swiggy @zomato They will have t...       TweetsAnup
# 1   RT @bk191305: @zomatocare meri id 14 dec 2022 ...         bk191305
# 2   Zomato flirting skills &gt;&gt;&gt;&gt; \n\n@z...       Rk__mishra
# 3   @zomatocare meri id 14 dec 2022 ko evening me ...         bk191305
# 4                      @GhazalAlagh Zomato and swiggy  thekomalchauhan
# ..                                                ...              ...
# 95  @zomato Morocco nahi pata but ye sahi nahi hai x(       itsmeachin
# 96  @deepigoyal Look what Zomato hume gives us on ...         vk770625
# 97  @Sanju27029909 @zomatocare @zomato The busines...       Peeyush_13
# 98  @zomato Zomato dekh ke tweet kar... Boycott ho...          imrpind
# 99  @zomato Aa gaye sullo ki chatne https://t.co/u...    Odia_Haalchal
#
# [100 rows x 15 columns]

# %%
df1.to_csv('./tweet_gopro.csv', index = False)

# %%
#df1.to_json('file.json', orient = 'split', compression = 'infer', index = 'false')

# %%
#df1 = pd.read_json('file.json', orient ='split', compression = 'infer')

# %%
#df1

# %%
d=pd.read_csv("tweet_gopro.csv")
